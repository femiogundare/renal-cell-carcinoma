# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import Lasso

# %%
data = pd.read_csv('filtered_expr.csv', index_col=0)

# %%
data.head()
# Out:
#                     TCGA-KL-8339-01A  TCGA-KO-8415-01A  TCGA-KL-8346-01A  \
# ENSG00000000003.15           17.3893            9.6741           27.4489
# ENSG00000000005.6             0.0000            0.1011            0.3794
# ENSG00000000419.13          124.3109           40.4987           32.5808
# ENSG00000000938.13            2.0287            3.1555            0.2392
# ENSG00000000971.16            1.0606            0.7341            0.7330
#
#                     TCGA-KM-8477-01A  TCGA-KL-8342-01A  TCGA-KM-8639-01A  \
# ENSG00000000003.15            6.2207           15.3781           99.5059
# ENSG00000000005.6             0.0458            0.3184            0.4429
# ENSG00000000419.13           42.3603           74.1792           68.9986
# ENSG00000000938.13            1.9185            4.2617            3.7473
# ENSG00000000971.16            0.8300           11.3033            2.1427
#
#                     TCGA-KO-8411-01A  TCGA-KN-8430-01A  TCGA-KL-8333-01A  \
# ...

# %%
data = data.T

# %%
data.head()
# Out:
#                   ENSG00000000003.15  ENSG00000000005.6  ENSG00000000419.13  \
# TCGA-KL-8339-01A             17.3893             0.0000            124.3109
# TCGA-KO-8415-01A              9.6741             0.1011             40.4987
# TCGA-KL-8346-01A             27.4489             0.3794             32.5808
# TCGA-KM-8477-01A              6.2207             0.0458             42.3603
# TCGA-KL-8342-01A             15.3781             0.3184             74.1792
#
#                   ENSG00000000938.13  ENSG00000000971.16  ENSG00000001036.14  \
# TCGA-KL-8339-01A              2.0287              1.0606             47.8806
# TCGA-KO-8415-01A              3.1555              0.7341             33.0038
# TCGA-KL-8346-01A              0.2392              0.7330             27.3080
# TCGA-KM-8477-01A              1.9185              0.8300             44.2112
# TCGA-KL-8342-01A              4.2617             11.3033             25.4678
#
# ...

# %%
data.shape
# Out:
# (897, 8540)

# %%
labels = pd.read_csv('labels.csv', index_col=0)

# %%
labels.head()
# Out:
#            project_id
# 1  Kidney Chromophobe
# 2  Kidney Chromophobe
# 3  Kidney Chromophobe
# 4  Kidney Chromophobe
# 5  Kidney Chromophobe

# %%
labels.value_counts()
# Out:
# project_id
# Kidney Renal Clear Cell Carcinoma        541
# Kidney Renal Papillary Cell Carcinoma    290
# Kidney Chromophobe                        66
# dtype: int64

# %%
genes = data.columns

# %%
genes
# Out:
# Index(['ENSG00000000003.15', 'ENSG00000000005.6', 'ENSG00000000419.13',
#        'ENSG00000000938.13', 'ENSG00000000971.16', 'ENSG00000001036.14',
#        'ENSG00000001084.13', 'ENSG00000001561.7', 'ENSG00000001617.12',
#        'ENSG00000001626.16',
#        ...
#        'ENSG00000287627.1', 'ENSG00000287649.1', 'ENSG00000287733.1',
#        'ENSG00000287770.1', 'ENSG00000287837.1', 'ENSG00000288003.1',
#        'ENSG00000288057.1', 'ENSG00000288066.1', 'ENSG00000288162.1',
#        'ENSG00000288545.1'],
#       dtype='object', length=8540)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, shuffle=True, random_state=42)

# %%
X_train.to_csv('training_set.csv')
X_test.to_csv('test_set.csv')

y_train.to_csv('training_labels.csv')
y_test.to_csv('test_labels.csv')
